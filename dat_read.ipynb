# %% [markdown]
# <a href="https://colab.research.google.com/github/sampiet/C_Fundamental/blob/master/dat_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import base64
import pandas as pd

# %% [markdown]
# Claim-Dat Authenitcation

# %%
api_url="https://www.dat.de/myClaim/rest/MyClaimExternalAuthenticationService/generateToken"
headers = {
    "Content-Type": "application/json",
    "DAT-AuthorizationToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJkYXQiLC..."
}
payload = {
    "request": {
        "customerNumber": 1346181,
        "customerLogin": "AGInsurance",
        "customerPassword": "AGInsurance01!!",
        "interfacePartnerNumber": 1342334,
        "interfacePartnerSignature": "717A307600A10F90A292D5A751108632179EEA950A03E4A4369F74BF8F8DC0EC"
    }
}
response = requests.post(api_url, headers=headers, json=payload, verify=False)
response.json()
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.dat.de'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....-KcDph9XQsOvRJFGWNY-3MLCtUp-PdJKp6Q8lfc7YYc'

# %% [markdown]
# Create and update Contract

# %%
api_url2="https://www.dat.de/myClaim/rest/MyClaimExternalService/createOrUpdateContract"
headers2 = {
    "Content-Type": "application/json",
    "DAT-AuthorizationToken":response.json()
    }
payload2 = {
    "contractType": "vro_calculation",
    "networkType": "FASTTRACKAI",
    "templateId":151147 ,
    "Dossier": {
        "Name": "enter_your_unique_name",
        "Country": "DE",
        "Language": "de_DE",
        "Currency": "EUR"
    }
}

payload2bis = {
    "contractType": "vro_calculation",
    "networkType": "FASTTRACKAI",
    "templateId": 151147,
    "Dossier": {
        "Name": "enter_your_unique_name",
        "Country": "DE",
        "Language": "de_DE",
        "Currency": "EUR",
        "Vehicle": {
            "VehicleIdentNumber": "WAUZZZ8RXAA105433",
            "SubModelName": {
                "origin": "dat",
                "value": "2.0 TDI quattro (125kW)"
            },
            "BaseModelName": {
                "origin": "dat",
                "value": "Q5 (8R)(2008->)"
            },
            "SubModel": "8",
            "DatECode": "010600110080001",
            "Container": "IT001",
            "VehicleTypeName": "Autovetture,SUV",
            "BaseModel": "11",
            "MainTypeGroupName": "Q 5",
            "Manufacturer": "60",
            "TokenOfVinResult": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJkYXQiLCJ0aW1lc3RhbXAiOjE2NzYwMjAxNDgxODMsImN1c3RvbWVyIjoiMzEzNDU1NyIsImludGVyZmFjZVBhcnRuZXIiOiIzMTMxNDExIiwidmluUmVzdWx0SGFzaCI6Imhhc2gwMV8xODcyNTM1NjYxIn0.4q4NPZT8hYE8lsF-kNaW5XZjPtCXX7ficWbnCv23En4"
        }
    }
}
response2 = requests.post(api_url2, headers=headers2, json=payload2)
response2.json()
# Out:
# 50615603

# %% [markdown]
# Upload Images

# %%
api_url3 = "https://www.dat.de/myClaim/rest/MyClaimExternalService/uploadAttachmentByIdentification"
headers3 = {
    "Content-Type": "application/json",
    "DAT-AuthorizationToken":response.json()
    }
payload3 = {
    "contractId": response2.json(),  # Replace with the actual contract ID
    "attachmentItem": {
        "fileName": "image12.jpg",
        "documentType": "Photos",  # Replace with the actual folder name
        "mimeType": "image/jpeg",
        "binaryData": "base64-encoded-file-content"  # Replace with actual base64 data of the file
    }
}
file_path = "/content/sample_data/05.jpg"  # Replace with the path to your file
with open(file_path, "rb") as file:
  file_content = file.read()
  payload3["attachmentItem"]["binaryData"] = base64.b64encode(file_content).decode("utf-8")
#payload3["attachmentItem"]["binaryData"] = image["attachmentItem"]["binaryData"]
response3 = requests.post(api_url3, headers=headers3, json=payload3)
response3.json()
# Out:
# {'code': 'dat:Server.Error',
#  'string': 'The folder already contains one file with this name image12.jpg',
#  'actor': 'eu.dat.myclaim.connect.p3rd.MyClaimExternalService'}

# %% [markdown]
# Change Contract Status

# %%
payload3["attachmentItem"]["binaryData"]
# Out:
# '...'

# %%
api_url4 = "https://www.dat.de/myClaim/rest/MyClaimExternalService/changeContractStatus"
headers4 = {
    "Content-Type": "application/json",
    "DAT-AuthorizationToken":response.json()
    }
payload4 = {
    "contractId": response2.json(),  # Replace with the actual contract ID
    "statusType": response3.json(),  # Replace with the desired status
    "comment": "your-commentw"  # Replace with any additional comment or note
}
response4 = requests.post(api_url4, headers=headers4, json=payload4)
response4.json()
# Out:
# {'code': 'dat:Server.WrongUsageOfStatusParameter',
#  'string': "either 'statusType' or the '<status>'-node must be set",
#  'actor': 'eu.dat.myclaim.connect.p3rd.MyClaimExternalService'}

# %%
api_url5 = "https://www.dat.de/myClaim/rest/MyClaimExternalService/getContractStatus"

# Headers (replace {{mc-token}} with the actual token obtained earlier)
headers5 = {
    "Content-Type": "application/json",
    "DAT-AuthorizationToken": response.json()  # Replace with the actual token
}

# Query Parameters
payload5 = {
    "contractId": response2.json()  # Replace with the actual contract ID
}

# Send the GET request
response5 = requests.post(api_url5, headers=headers5, json=payload5)
response5.json()
# Out:
# {'originalName': 'Processed',
#  'statusId': 142003,
#  'statusType': 'custom',
#  'icon': 'icon-status-ok1',
#  'name': 'Processed',
#  'description': 'Processed',
#  'networkType': 'FASTTRACKAI'}

# %% [markdown]
# Get AI result : get-contratc

# %%
contractId=response2.json()
customerNumber=1346181
api_url6=f"https://prod-api.wedat.eu/contract/get-contract?contractId={contractId}&customerNumber={customerNumber}".format(contractId,customerNumber )
headers6 = {
    "Content-Type": "application/json",
    "DAT-AuthorizationToken": response.json()  # Replace with the actual token
}

# Query Parameters
payload6 = {
    "contractId": response2.json()  # Replace with the actual contract ID
}
response6 = requests.get(api_url6, headers=headers6, json=payload6)
response6.json()
# Out:
# {'customTemplateData': {'entry': [{'key': 'customAIJsonResponse',
#     'value': {'_text': '{"aiResults":{"damageSummaries":[{"datId":"Door - rear left","severity":20,"damageList":[{"damageType":"scratch"}]},{"datId":"Sidewall - rear left","severity":60,"damageList":[{"damageType":"scratch"}]}],"aiPipelineImages":[{"fileName":"1732873889_image1.jpg","imageId":"image_0","classification":"inScope"}]}}',
#      'type': 'xs:string'}}]}}

# %%
data2 = {
    "customTemplateData": {
        "entry": [
            {
                "key": "customAIJsonResponse",
                "value": {
                    "_text": "{\"aiResults\":{\"damageSummaries\":[{\"datId\":\"Door - rear left\",\"severity\":20,\"damageList\":[{\"damageType\":\"scratch\"}]},{\"datId\":\"Sidewall - rear left\",\"severity\":60,\"damageList\":[{\"damageType\":\"scratch\"}]}],\"aiPipelineImages\":[{\"fileName\":\"1732873889_image1.jpg\",\"imageId\":\"image_0\",\"classification\":\"inScope\"}]}}",
                    "type": "xs:string"
                }
            }
        ]
    }
}
data=response6.json()

# %%
custom_ai_json_response = data["customTemplateData"]["entry"][0]["value"]["_text"]
parsed_data = json.loads(custom_ai_json_response)
# Extract damage summaries and AI pipeline images
damage_summaries = parsed_data["aiResults"]["damageSummaries"]
ai_pipeline_images = parsed_data["aiResults"]["aiPipelineImages"]
# Convert to DataFrames
damage_summaries_df = pd.DataFrame(damage_summaries)
ai_pipeline_images_df = pd.DataFrame(ai_pipeline_images)
# Expand nested lists in 'damageList' column of damage_summaries_df
damage_summaries_df = damage_summaries_df.explode('damageList')
damage_summaries_df['damageType'] = damage_summaries_df['damageList'].apply(lambda x: x['damageType'] if x else None)
damage_summaries_df.drop(columns=['damageList'], inplace=True)
damage_summaries_df['fileName']=ai_pipeline_images_df["fileName"][0]
damage_summaries_df['imageId']=ai_pipeline_images_df["imageId"][0]
damage_summaries_df['classification']=ai_pipeline_images_df["classification"][0]
damage_summaries_df['compteur']=20

# %%
damage_summaries_df
# Out:
#                   datId  severity damageType               fileName  imageId  \
# 0      Door - rear left        20    scratch  1732873889_image1.jpg  image_0
# 1  Sidewall - rear left        60    scratch  1732873889_image1.jpg  image_0
#
#   classification  compteur
# 0        inScope        20
# 1        inScope        20

# %%
damage_summaries_df
# Out:
#                   datId  severity damageType               fileName  imageId  \
# 0      Door - rear left        20    scratch  1732873889_image1.jpg  image_0
# 1  Sidewall - rear left        60    scratch  1732873889_image1.jpg  image_0
#
#   classification  compteur
# 0        inScope        20
# 1        inScope        20
